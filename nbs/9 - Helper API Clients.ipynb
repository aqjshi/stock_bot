# %%
import setup
setup.init_django()
# Out:
# 0pEnqPfhRk7bYu5LSa7ppMuKfqr21kck

# %%
import helpers.clients as helper_clients

# %%
# dataset_a = helper_clients.AlphaVantageAPIClient().get_stock_data()

# %%
dataset_b = helper_clients.PolygonAPIClient().get_stock_data()

# %%
dataset_b
# Out:
# [{'open_price': 221.98,
#   'close_price': 222.0501,
#   'high_price': 222.0598,
#   'low_price': 221.89,
#   'number_of_trades': 333,
#   'volume': 11156,
#   'volume_weighted_average': 222.0035,
#   'raw_timestamp': 1737507300000,
#   'time': datetime.datetime(2025, 1, 22, 0, 55, tzinfo=<UTC>)},
#  {'open_price': 222.04,
#   'close_price': 221.9997,
#   'high_price': 222.05,
#   'low_price': 221.86,
#   'number_of_trades': 311,
#   'volume': 9946,
#   'volume_weighted_average': 222.0031,
#   'raw_timestamp': 1737507000000,
#   'time': datetime.datetime(2025, 1, 22, 0, 50, tzinfo=<UTC>)},
#  {'open_price': 221.88,
#   'close_price': 222.0397,
#   'high_price': 222.05,
#   'low_price': 221.8788,
#   'number_of_trades': 257,
#   'volume': 8995,
#   'volume_weighted_average': 221.988,
#   'raw_timestamp': 1737506700000,
#   'time': datetime.datetime(2025, 1, 22, 0, 45, tzinfo=<UTC>)},
#  {'open_price': 222.15,
#   'close_price': 221.88,
#   'high_price': 222.17,
# ...

# %%
dataset_c = helper_clients.PolygonAPIClient().get_sma_data()

dataset_d = helper_clients.PolygonAPIClient().get_ema_data()
dataset_e = helper_clients.PolygonAPIClient().get_macd_data()
dataset_f = helper_clients.PolygonAPIClient().get_rsi_data()
# Out:
# https://api.polygon.io/v1/indicators/sma/AAPL/?timestamp.gte=2025-01-01&timestamp.lte=2025-01-21&timespan=minute&adjusted=True&window=50&series_type=close&order=desc&limit=5000&apiKey=0pEnqPfhRk7bYu5LSa7ppMuKfqr21kck
# ...

# %%
# dataset_c = helper_clients.FREDAPIClient().get_series_data()

# %%
dataset_c
# Out:
# [{'value': 221.8762579999998,
#   'raw_timestamp': 1737504000000,
#   'time': datetime.datetime(2025, 1, 22, 0, 0, tzinfo=<UTC>)},
#  {'value': 221.86585799999978,
#   'raw_timestamp': 1737503940000,
#   'time': datetime.datetime(2025, 1, 21, 23, 59, tzinfo=<UTC>)},
#  {'value': 221.8572299999998,
#   'raw_timestamp': 1737503880000,
#   'time': datetime.datetime(2025, 1, 21, 23, 58, tzinfo=<UTC>)},
#  {'value': 221.8490299999998,
#   'raw_timestamp': 1737503820000,
#   'time': datetime.datetime(2025, 1, 21, 23, 57, tzinfo=<UTC>)},
#  {'value': 221.84187399999982,
#   'raw_timestamp': 1737503760000,
#   'time': datetime.datetime(2025, 1, 21, 23, 56, tzinfo=<UTC>)},
#  {'value': 221.8294299999998,
#   'raw_timestamp': 1737503700000,
#   'time': datetime.datetime(2025, 1, 21, 23, 55, tzinfo=<UTC>)},
#  {'value': 221.81662999999983,
#   'raw_timestamp': 1737503640000,
#   'time': datetime.datetime(2025, 1, 21, 23, 54, tzinfo=<UTC>)},
#  {'value': 221.8046299999998,
# ...

# %%
dataset_d
# Out:
# [{'value': 221.9377285032484,
#   'raw_timestamp': 1737504000000,
#   'time': datetime.datetime(2025, 1, 22, 0, 0, tzinfo=<UTC>)},
#  {'value': 221.9384521156259,
#   'raw_timestamp': 1737503940000,
#   'time': datetime.datetime(2025, 1, 21, 23, 59, tzinfo=<UTC>)},
#  {'value': 221.93916444687594,
#   'raw_timestamp': 1737503880000,
#   'time': datetime.datetime(2025, 1, 21, 23, 58, tzinfo=<UTC>)},
#  {'value': 221.94076299572802,
#   'raw_timestamp': 1737503820000,
#   'time': datetime.datetime(2025, 1, 21, 23, 57, tzinfo=<UTC>)},
#  {'value': 221.93843495473732,
#   'raw_timestamp': 1737503760000,
#   'time': datetime.datetime(2025, 1, 21, 23, 56, tzinfo=<UTC>)},
#  {'value': 221.9363302590123,
#   'raw_timestamp': 1737503700000,
#   'time': datetime.datetime(2025, 1, 21, 23, 55, tzinfo=<UTC>)},
#  {'value': 221.933731494074,
#   'raw_timestamp': 1737503640000,
#   'time': datetime.datetime(2025, 1, 21, 23, 54, tzinfo=<UTC>)},
#  {'value': 221.93102665709742,
# ...

# %%
dataset_e
# Out:
# [{'histogram': -0.029763533741588823,
#   'signal': 0.030934681738289307,
#   'timestamp': 1737504000000,
#   'value': 0.0011711479967004834,
#   'raw_timestamp': None,
#   'time': datetime.datetime(2025, 1, 22, 0, 0, tzinfo=<UTC>)},
#  {'histogram': -0.030407727437028853,
#   'signal': 0.03837556517368651,
#   'timestamp': 1737503940000,
#   'value': 0.007967837736657657,
#   'raw_timestamp': None,
#   'time': datetime.datetime(2025, 1, 21, 23, 59, tzinfo=<UTC>)},
#  {'histogram': -0.029552325668028664,
#   'signal': 0.04597749703294372,
#   'timestamp': 1737503880000,
#   'value': 0.01642517136491506,
#   'raw_timestamp': None,
#   'time': datetime.datetime(2025, 1, 21, 23, 58, tzinfo=<UTC>)},
#  {'histogram': -0.02424650374660548,
#   'signal': 0.053365578449950886,
#   'timestamp': 1737503820000,
#   'value': 0.029119074703345404,
#   'raw_timestamp': None,
#   'time': datetime.datetime(2025, 1, 21, 23, 57, tzinfo=<UTC>)},
#  {'histogram': -0.024487461417899196,
# ...

# %%
dataset_f
# Out:
# [{'value': 42.70446687062971,
#   'raw_timestamp': 1737504000000,
#   'time': datetime.datetime(2025, 1, 22, 0, 0, tzinfo=<UTC>)},
#  {'value': 42.797008350533204,
#   'raw_timestamp': 1737503940000,
#   'time': datetime.datetime(2025, 1, 21, 23, 59, tzinfo=<UTC>)},
#  {'value': 40.27313555209722,
#   'raw_timestamp': 1737503880000,
#   'time': datetime.datetime(2025, 1, 21, 23, 58, tzinfo=<UTC>)},
#  {'value': 49.769216310057786,
#   'raw_timestamp': 1737503820000,
#   'time': datetime.datetime(2025, 1, 21, 23, 57, tzinfo=<UTC>)},
#  {'value': 48.876485084868364,
#   'raw_timestamp': 1737503760000,
#   'time': datetime.datetime(2025, 1, 21, 23, 56, tzinfo=<UTC>)},
#  {'value': 49.93295902404555,
#   'raw_timestamp': 1737503700000,
#   'time': datetime.datetime(2025, 1, 21, 23, 55, tzinfo=<UTC>)},
#  {'value': 49.932959024045545,
#   'raw_timestamp': 1737503640000,
#   'time': datetime.datetime(2025, 1, 21, 23, 54, tzinfo=<UTC>)},
#  {'value': 49.98885929749333,
# ...

# %%
dataset_b
# Out:
# [{'open_price': 185.34,
#   'close_price': 185.1,
#   'high_price': 185.34,
#   'low_price': 184.97,
#   'number_of_trades': 266,
#   'volume': 7053,
#   'volume_weighted_average': 185.0455,
#   'raw_timestamp': 1704790800000,
#   'time': datetime.datetime(2024, 1, 9, 9, 0, tzinfo=<UTC>)},
#  {'open_price': 185.07,
#   'close_price': 184.95,
#   'high_price': 185.07,
#   'low_price': 184.92,
#   'number_of_trades': 165,
#   'volume': 7461,
#   'volume_weighted_average': 184.9948,
#   'raw_timestamp': 1704791100000,
#   'time': datetime.datetime(2024, 1, 9, 9, 5, tzinfo=<UTC>)},
#  {'open_price': 184.95,
#   'close_price': 185,
#   'high_price': 185,
#   'low_price': 184.86,
#   'number_of_trades': 68,
#   'volume': 5547,
#   'volume_weighted_average': 184.935,
#   'raw_timestamp': 1704791400000,
#   'time': datetime.datetime(2024, 1, 9, 9, 10, tzinfo=<UTC>)},
#  {'open_price': 184.93,
#   'close_price': 184.99,
#   'high_price': 184.99,
#   'low_price': 184.85,
# ...
