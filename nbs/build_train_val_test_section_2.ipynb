# %%
import setup
setup.init_django()

# %%
from market.models import StockQuote

# %%
from django.db.models import Avg, F, RowRange, Window
from django.utils import timezone
from datetime import timedelta
from decimal import Decimal

# %%
days_ago = 30
now = timezone.now()
start_date = now - timedelta(days=30)
end_date = now

qs = StockQuote.objects.filter(company__ticker="AAPL", time__range=(start_date, end_date))
qs.count()
# Out:
# 8109

# %%
from django.utils.timezone import make_aware
import datetime
import pytz

# Define the parameter k
k = 30  # for example, 30 minutes after the current time

# for the first object in qs print the available static variable names to parse
first_object = qs[7110]
print(first_object.__dict__.keys())
print(first_object.company)
print(first_object.company.ticker)
print(first_object.close_price)

# turn UTC TIME Jan. 10, 2025, 9 p.m. into Jan 10, 2025, 04:00 PM (EST)
print("current object time: ", first_object.time)  # this gets you utc time
eastern = pytz.timezone('US/Eastern')

# Convert the date to k minutes after the current time
localized_time = first_object.time.astimezone(eastern)
print(localized_time)
print(localized_time.hour)

# Add k minutes to the current time
target_est = localized_time + timedelta(minutes=k)
target_utc = target_est.astimezone(datetime.timezone.utc)
print(f"converted time to {k} minutes after current time: ", target_est)

# Query for the same date but k minutes after the current time
value_after_k_minutes = StockQuote.objects.filter(company__ticker="AAPL", time=target_utc).first()
print(value_after_k_minutes.close_price if value_after_k_minutes else "No data available")
print("Time for the object: ", value_after_k_minutes.time if value_after_k_minutes else "No data available")
# Out:
# dict_keys(['_state', 'id', 'company_id', 'open_price', 'close_price', 'high_price', 'low_price', 'number_of_trades', 'volume', 'volume_weighted_average', 'raw_timestamp', 'time', 'sma_value', 'ema_value', 'macd_histogram', 'macd_signal', 'macd_value', 'rsi_value', 'effr_daily_rate', 'effr_rate_percentile_1st', 'effr_rate_percentile_25th', 'effr_rate_percentile_75th', 'effr_rate_percentile_99th', 'effr_target_rate_from', 'effr_target_rate_to', 'effr_trading_volume'])
# Company object (22)
# AAPL
# 228.0000
# current object time:  2025-01-16 21:32:00+00:00
# 2025-01-16 16:32:00-05:00
# 16
# converted time to 30 minutes after current time:  2025-01-16 17:02:00-05:00
# 228.1800
# Time for the object:  2025-01-16 22:02:00+00:00

# %%
# Initialize the queryset
qs = None
qs = StockQuote.objects.filter(company__ticker="AAPL")

# Initialize a list to store the results
close_price_after_k_window_dataset = []

# Iterate over each object in the queryset
for obj in qs:
    # Localize the time to Eastern timezone
    localized_time = obj.time.astimezone(eastern)
    
    # Add k minutes to the localized time
    target_est = localized_time + timedelta(minutes=k)
    target_utc = target_est.astimezone(datetime.timezone.utc)
    
    # Query for the same date but k minutes after the current time
    value_after_k_minutes = StockQuote.objects.filter(company__ticker="AAPL", time=target_utc).first()
    
    # Append the result to the dataset
    close_price_after_k_window_dataset.append({
        'original_time': obj.time,
        'close_price': obj.close_price,
        'time_after_k_minutes': target_utc,
        'close_price_after_k_minutes': value_after_k_minutes.close_price if value_after_k_minutes else None
    })

# Print the number of items with a valid close_price_after_k_window_value
valid_close_price_after_k_window_value = sum(1 for item in close_price_after_k_window_dataset if item['close_price_after_k_minutes'] is not None)
print(f"Number of items with a valid close_price_after_k_window_value: {valid_close_price_after_k_window_value}")
# Print the first 10 items in the dataset
for item in close_price_after_k_window_dataset[:1000]:
    print(item)
# Out:
# Number of items with a valid close_price_after_k_window_value: 6807
# {'original_time': datetime.datetime(2025, 1, 4, 0, 59, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3908'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 29, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 56, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3499'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 26, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 47, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 17, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 46, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3001'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 16, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 42, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 12, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 41, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 11, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 39, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 9, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 37, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 7, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 36, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1701'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 6, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 35, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 5, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 33, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 1, 3, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 25, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 55, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 24, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 54, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 22, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 52, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 21, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2120'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 51, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 16, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 46, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3001')}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 14, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1764'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 44, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 13, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1803'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 43, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 7, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1967'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 37, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 4, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 34, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 3, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 33, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2500')}
# {'original_time': datetime.datetime(2025, 1, 4, 0, 1, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 31, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 58, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 28, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 56, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 26, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2800')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2991'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 50, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2711'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 20, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2500')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 45, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 15, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 41, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2702'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 11, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 35, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 5, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 34, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 4, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1700')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 33, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 3, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 30, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 4, 0, 0, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 27, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 57, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2711')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 17, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 47, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 13, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 43, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 12, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 42, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 8, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 38, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 6, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 36, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 5, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 35, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3400')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 4, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 34, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3300')}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 1, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 31, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 23, 0, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 30, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3500')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3000')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 52, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 22, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 48, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1994'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 18, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 47, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1979'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 17, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3000')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 44, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 14, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 42, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2408'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 12, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2200')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 37, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 7, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 33, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 3, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 31, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 1, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2800')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 30, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 23, 0, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2400')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 28, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 58, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 27, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 57, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1600')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 25, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 55, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1600')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 24, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 54, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 23, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 53, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 19, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 49, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 22, 12, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 42, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2408')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 58, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 28, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1400')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1500')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1300')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 54, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1399'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 24, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1500')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1084'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1400')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 52, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 22, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 51, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 21, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 49, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 19, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1500')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 48, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 18, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 46, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 16, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 45, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 15, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 44, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 14, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 41, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 11, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 40, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 10, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 39, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 9, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 38, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 8, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 37, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 7, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 36, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 6, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 35, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 5, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 34, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 4, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 31, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 1, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 30, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 22, 0, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 29, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 59, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 28, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 58, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 27, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 57, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0500')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 26, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1501'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 56, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 24, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 54, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1399')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 23, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 53, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1084')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 22, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 52, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 21, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1399'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 51, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1400')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 19, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 49, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1600')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 18, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 48, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1900')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 17, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 47, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 16, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 46, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1100')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 15, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 45, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1100')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 14, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 44, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1600')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 13, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 43, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 12, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 42, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 11, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 41, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2200')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 10, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 40, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2100')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 9, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 39, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 7, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 37, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1200')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 6, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 36, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1400')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 5, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 35, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1500')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 4, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 34, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1200')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 3, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 33, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 2, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 32, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 1, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 31, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 21, 0, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 30, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0500')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 59, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 29, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 58, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 28, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.3000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 56, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2150'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 26, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1501')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 54, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9150'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 24, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1400')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0900')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 52, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8550'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 22, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 51, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 21, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1399')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 50, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 20, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 49, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7950'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 19, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 48, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 18, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 47, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 17, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0500')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 46, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 16, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 45, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 15, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 44, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 14, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 43, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 13, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2200')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 42, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7650'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 12, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 41, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 11, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 40, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 10, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1100')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 39, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 9, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2200')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 38, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 8, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': None}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 37, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7350'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 7, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 36, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 6, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 35, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7350'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 5, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 34, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 4, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 33, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 3, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 32, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7750'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 2, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 31, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7750'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 1, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 30, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 21, 0, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 29, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 59, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 28, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 58, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3400')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 27, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8935'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 57, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.3000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 26, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8580'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 56, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.2150')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 25, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8701'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 55, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.1700')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 24, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8889'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 54, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.9150')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 23, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 53, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6700')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 22, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 52, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8550')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 21, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 51, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7500')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9575'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 19, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9020'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 49, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7950')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 18, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 48, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 17, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 47, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0400')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 16, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 46, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('243.0200')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 15, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8969'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 45, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.9000')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 14, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 44, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8900')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 13, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.8590'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 43, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 12, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 42, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7650')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 11, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9850'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 41, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 10, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 40, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7300')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 9, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 39, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7400')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 8, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 38, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6200')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 7, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9689'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 37, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7350')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 6, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9558'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 36, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7400')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 5, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9578'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 35, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7350')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 4, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9150'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 34, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7600')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 3, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 33, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6800')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 2, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.9900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 32, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7750')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 1, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.0000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 31, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7750')}
# {'original_time': datetime.datetime(2025, 1, 3, 20, 0, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 30, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7600')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 59, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 29, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8500')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 58, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2510'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 28, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8700')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8935')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 56, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.2400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 26, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8580')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1497'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8701')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 54, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1448'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 24, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8889')}
# {'original_time': datetime.datetime(2025, 1, 3, 19, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('243.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 3, 20, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.9200')}
# ...
# {'original_time': datetime.datetime(2025, 1, 2, 19, 41, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4050'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 11, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.9200')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 40, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3850'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 10, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8076')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 39, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4150'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 9, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.8100')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 38, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 8, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6812')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 37, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3692'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 7, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.5500')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 36, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2469'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 6, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 35, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 5, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4500')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 34, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 4, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 33, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 3, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3400')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 32, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 2, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2200')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 31, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 1, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.0700')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 30, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 20, 0, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.0700')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 29, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4884'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 59, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('241.9600')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 28, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 58, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.1300')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 27, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.7593'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 57, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.0300')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 26, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6050'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 56, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2700')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 25, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 55, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3000')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 24, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.5838'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 54, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 23, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 53, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3800')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 22, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 52, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.5200')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 21, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 51, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.5400')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 20, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 50, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4700')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 19, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 49, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4125')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 18, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 48, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.5199')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 17, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 47, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 16, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 46, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2000')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 15, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 45, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 14, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 44, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3400')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 13, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 43, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3361')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 12, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 42, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 11, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 41, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4050')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 10, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4450'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 40, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3850')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 9, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 39, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4150')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 8, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 38, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4000')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 7, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 37, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3692')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 6, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6350'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 36, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2469')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 5, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 35, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.1900')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 4, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 34, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4800')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 3, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 33, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4600')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 2, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 32, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4800')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 1, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.0700'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 31, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4600')}
# {'original_time': datetime.datetime(2025, 1, 2, 19, 0, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 30, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3200')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 59, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2300'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 29, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4884')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 58, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1150'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 28, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6500')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 57, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.0400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 27, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.7593')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 56, tzinfo=datetime.timezone.utc), 'close_price': Decimal('241.9800'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 26, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6050')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 55, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.0200'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 25, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.6300')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 54, tzinfo=datetime.timezone.utc), 'close_price': Decimal('241.8400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 24, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.5838')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 53, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.0320'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 23, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4700')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 52, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.0900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 22, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.4300')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 51, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.1900'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 21, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3400')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 50, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2350'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 20, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2400')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 49, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.2600'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 19, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3200')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 48, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.3500'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 18, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3400')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 47, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.5000'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 17, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2900')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 46, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.5100'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 16, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2400')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 45, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6060'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 15, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.2700')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 44, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.6262'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 14, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.1900')}
# {'original_time': datetime.datetime(2025, 1, 2, 18, 43, tzinfo=datetime.timezone.utc), 'close_price': Decimal('242.4400'), 'time_after_k_minutes': datetime.datetime(2025, 1, 2, 19, 13, tzinfo=datetime.timezone.utc), 'close_price_after_k_minutes': Decimal('242.3300')}

# %%
# Let A be Predicted Price Change: Literal["1", "-1"] for 1 being greater than current price
# Let B be Given time series past data
# we want to solve for P (A | B) 
import setup
setup.init_django()
import helpers.clients as helper_clients
from datetime import datetime, timedelta

# class TimeSeriesBlock(int: lookback_depth, int: k_projection)
from django.db import models
from dataclasses import dataclass
from market.models import Company, StockQuote


@dataclass
class TimeSeriesBlock:
    ticker: str = "AAPL"
    timestamp = models.DateTimeField(auto_now_add=True)
    step_size: str = "minute"
    # number of the most recent time series objects we store given that the objects are sorted ascending, and less than current time
    l_lookback_depth: int = 15 

    # number of the most recent time series objects we store given that the objects are sorted ascending, and greater than current time
    k_projection_depth: int = 15
    k_projection_steps: int = 15
